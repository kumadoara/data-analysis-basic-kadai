# %%
import numpy as np

# %%
# 行列の積を計算
A = np.array([[0,2],[2,3],[4,5]])
B = np.array([[0,1,2,3],[4,5,6,7]])
AB_array = np.dot(A,B)
AB_array
# Out:
# array([[ 8, 10, 12, 14],
#        [12, 17, 22, 27],
#        [20, 29, 38, 47]])

# %%
# 要素の最大値
AB_array.max()
# Out:
# 47
